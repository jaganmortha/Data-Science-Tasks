# %% [markdown]
# # Exploratory Data Analysis
#
# ## Import packages

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Shows plots in jupyter notebook
# %matplotlib inline

# Set plot style
sns.set(color_codes=True)

# %% [markdown]
# ---
#
# ## Loading data with Pandas

# %%
client_df = pd.read_csv('./client_data.csv')
price_df = pd.read_csv('./price_data.csv')

# %%
print(client_df.shape)
print(price_df.shape)
# Out:
# (14606, 26)
# (193002, 8)

# %% [markdown]
# You can view the first 3 rows of a dataframe using the `head` method. Similarly, if you wanted to see the last 3, you can use `tail(3)`

# %%
client_df.head(10)
# Out:
#                                  id                     channel_sales  \
# 0  24011ae4ebbe3035111d65fa7c15bc57  foosdfpfkusacimwkcsosbicdxkicaua
# 1  d29c2c54acc38ff3c0614d0a653813dd                           MISSING
# 2  764c75f661154dac3a6c254cd082ea7d  foosdfpfkusacimwkcsosbicdxkicaua
# 3  bba03439a292a1e166f80264c16191cb  lmkebamcaaclubfxadlmueccxoimlema
# 4  149d57cf92fc41cf94415803a877cb4b                           MISSING
# 5  1aa498825382410b098937d65c4ec26d  usilxuppasemubllopkaafesmlibmsdf
# 6  7ab4bf4878d8f7661dfc20e9b8e18011  foosdfpfkusacimwkcsosbicdxkicaua
# 7  01495c955be7ec5e7f3203406785aae0  foosdfpfkusacimwkcsosbicdxkicaua
# 8  f53a254b1115634330c12c7fdbf7958a  usilxuppasemubllopkaafesmlibmsdf
# 9  10c1b2f97a2d2a6f10299dc213d1a370  lmkebamcaaclubfxadlmueccxoimlema
#
#    cons_12m  cons_gas_12m  cons_last_month  date_activ    date_end  \
# 0         0         54946                0  2013-06-15  2016-06-15
# ...

# %%
price_df.head(10)
# Out:
#                                  id  price_date  price_off_peak_var  \
# 0  038af19179925da21a25619c5a24b745  2015-01-01            0.151367
# 1  038af19179925da21a25619c5a24b745  2015-02-01            0.151367
# 2  038af19179925da21a25619c5a24b745  2015-03-01            0.151367
# 3  038af19179925da21a25619c5a24b745  2015-04-01            0.149626
# 4  038af19179925da21a25619c5a24b745  2015-05-01            0.149626
# 5  038af19179925da21a25619c5a24b745  2015-06-01            0.149626
# 6  038af19179925da21a25619c5a24b745  2015-07-01            0.150321
# 7  038af19179925da21a25619c5a24b745  2015-08-01            0.145859
# 8  038af19179925da21a25619c5a24b745  2015-09-01            0.145859
# 9  038af19179925da21a25619c5a24b745  2015-10-01            0.145859
#
#    price_peak_var  price_mid_peak_var  price_off_peak_fix  price_peak_fix  \
# 0             0.0                 0.0           44.266931             0.0
# ...

# %% [markdown]
# ---
#
# ## Descriptive statistics of data
#
# ### Data types
#
# It is useful to first understand the data that you're dealing with along with the data types of each column. The data types may dictate how you transform and engineer features.
#
# To get an overview of the data types within a data frame, use the `info()` method.

# %%
client_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14606 entries, 0 to 14605
# Data columns (total 26 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              14606 non-null  object
#  1   channel_sales                   14606 non-null  object
#  2   cons_12m                        14606 non-null  int64
#  3   cons_gas_12m                    14606 non-null  int64
#  4   cons_last_month                 14606 non-null  int64
#  5   date_activ                      14606 non-null  object
#  6   date_end                        14606 non-null  object
#  7   date_modif_prod                 14606 non-null  object
#  8   date_renewal                    14606 non-null  object
#  9   forecast_cons_12m               14606 non-null  float64
#  10  forecast_cons_year              14606 non-null  int64
#  11  forecast_discount_energy        14606 non-null  float64
# ...

# %%
price_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193002 entries, 0 to 193001
# Data columns (total 8 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   id                  193002 non-null  object
#  1   price_date          193002 non-null  object
#  2   price_off_peak_var  193002 non-null  float64
#  3   price_peak_var      193002 non-null  float64
#  4   price_mid_peak_var  193002 non-null  float64
#  5   price_off_peak_fix  193002 non-null  float64
#  6   price_peak_fix      193002 non-null  float64
#  7   price_mid_peak_fix  193002 non-null  float64
# dtypes: float64(6), object(2)
# memory usage: 11.8+ MB

# %% [markdown]
# ### Statistics
#
# Now let's look at some statistics about the datasets. We can do this by using the `describe()` method.

# %%
client_df.describe()
# Out:
#            cons_12m  cons_gas_12m  cons_last_month  forecast_cons_12m  \
# count  1.460600e+04  1.460600e+04     14606.000000       14606.000000
# mean   1.592203e+05  2.809238e+04     16090.269752        1868.614880
# std    5.734653e+05  1.629731e+05     64364.196422        2387.571531
# min    0.000000e+00  0.000000e+00         0.000000           0.000000
# 25%    5.674750e+03  0.000000e+00         0.000000         494.995000
# 50%    1.411550e+04  0.000000e+00       792.500000        1112.875000
# 75%    4.076375e+04  0.000000e+00      3383.000000        2401.790000
# max    6.207104e+06  4.154590e+06    771203.000000       82902.830000
#
#        forecast_cons_year  forecast_discount_energy  forecast_meter_rent_12m  \
# count        14606.000000              14606.000000             14606.000000
# mean          1399.762906                  0.966726                63.086871
# std           3247.786255                  5.108289                66.165783
# ...

# %%
price_df.describe()
# Out:
#        price_off_peak_var  price_peak_var  price_mid_peak_var  \
# count       193002.000000   193002.000000       193002.000000
# mean             0.141027        0.054630            0.030496
# std              0.025032        0.049924            0.036298
# min              0.000000        0.000000            0.000000
# 25%              0.125976        0.000000            0.000000
# 50%              0.146033        0.085483            0.000000
# 75%              0.151635        0.101673            0.072558
# max              0.280700        0.229788            0.114102
#
#        price_off_peak_fix  price_peak_fix  price_mid_peak_fix
# count       193002.000000   193002.000000       193002.000000
# mean            43.334477       10.622875            6.409984
# std              5.410297       12.841895            7.773592
# min              0.000000        0.000000            0.000000
# 25%             40.728885        0.000000            0.000000
# ...

# %% [markdown]
# ### Summarizing categorical columns

# %%
client_df.columns
# Out:
# Index(['id', 'channel_sales', 'cons_12m', 'cons_gas_12m', 'cons_last_month',
#        'date_activ', 'date_end', 'date_modif_prod', 'date_renewal',
#        'forecast_cons_12m', 'forecast_cons_year', 'forecast_discount_energy',
#        'forecast_meter_rent_12m', 'forecast_price_energy_off_peak',
#        'forecast_price_energy_peak', 'forecast_price_pow_off_peak', 'has_gas',
#        'imp_cons', 'margin_gross_pow_ele', 'margin_net_pow_ele', 'nb_prod_act',
#        'net_margin', 'num_years_antig', 'origin_up', 'pow_max', 'churn'],
#       dtype='object')

# %%
# Finding the different sales channels through which clients were acquired significantly
client_df['channel_sales'].value_counts()
# Out:
# channel_sales
# foosdfpfkusacimwkcsosbicdxkicaua    6754
# MISSING                             3725
# lmkebamcaaclubfxadlmueccxoimlema    1843
# usilxuppasemubllopkaafesmlibmsdf    1375
# ewpakwlliwisiwduibdlfmalxowmwpci     893
# sddiedcslfslkckwlfkdpoeeailfpeds      11
# epumfxlbckeskwekxbiuasklxalciiuu       3
# fixdbufsefwooaasfcxdxadsiekoceaa       2
# Name: count, dtype: int64

# %%
client_df['has_gas'].value_counts()
# Out:
# has_gas
# f    11955
# t     2651
# Name: count, dtype: int64

# %%
# Grouping the dataframe by 'channel_sales' and 'has_gas' to find out which combination contribute to maximum churn
churn_count = client_df.groupby(['channel_sales','has_gas'], as_index=False).count()[['channel_sales','has_gas','churn']]
churn_rate = client_df.groupby(['channel_sales','has_gas'], as_index=False).sum()[['channel_sales','has_gas','churn']]

# %%
churn_rate['churn_count'] = churn_count['churn']
# Calculting churn percentage
churn_rate['churn_percentage'] = churn_rate['churn']/churn_count['churn']
churn_rate['churn_percentage'] = churn_rate['churn_percentage']*100
churn_rate
# Out:
#                        channel_sales has_gas  churn  churn_count  \
# 0                            MISSING       f    234         2974
# 1                            MISSING       t     49          751
# 2   epumfxlbckeskwekxbiuasklxalciiuu       f      0            3
# 3   ewpakwlliwisiwduibdlfmalxowmwpci       f     64          734
# 4   ewpakwlliwisiwduibdlfmalxowmwpci       t     11          159
# 5   fixdbufsefwooaasfcxdxadsiekoceaa       f      0            1
# 6   fixdbufsefwooaasfcxdxadsiekoceaa       t      0            1
# 7   foosdfpfkusacimwkcsosbicdxkicaua       f    705         5656
# 8   foosdfpfkusacimwkcsosbicdxkicaua       t    115         1098
# 9   lmkebamcaaclubfxadlmueccxoimlema       f     82         1440
# 10  lmkebamcaaclubfxadlmueccxoimlema       t     21          403
# 11  sddiedcslfslkckwlfkdpoeeailfpeds       f      0           11
# 12  usilxuppasemubllopkaafesmlibmsdf       f    117         1136
# ...

# %%
gas_count = client_df.groupby(['has_gas'], as_index=False).count()[['has_gas','churn']]

# %%
gas_churn = client_df.groupby(['has_gas'], as_index=False).sum()[['has_gas','churn']]

# %%
gas_churn['churn_rate'] = gas_churn['churn']/gas_count['churn']

# %%
gas_churn
# Out:
#   has_gas  churn  churn_rate
# 0       f   1202    0.100544
# 1       t    217    0.081856

# %%
client_df[['cons_12m', 'cons_gas_12m', 'cons_last_month',
       'forecast_cons_12m', 'forecast_cons_year', 'forecast_discount_energy',
       'forecast_meter_rent_12m', 'forecast_price_energy_off_peak',
       'forecast_price_energy_peak', 'forecast_price_pow_off_peak',
       'imp_cons', 'margin_gross_pow_ele', 'margin_net_pow_ele', 'nb_prod_act',
       'net_margin', 'num_years_antig', 'pow_max', 'churn']].corr()
# Out:
#                                 cons_12m  cons_gas_12m  cons_last_month  \
# cons_12m                        1.000000      0.488474         0.968212
# cons_gas_12m                    0.488474      1.000000         0.507007
# cons_last_month                 0.968212      0.507007         1.000000
# forecast_cons_12m               0.193947      0.084359         0.177773
# forecast_cons_year              0.167093      0.080934         0.193574
# forecast_discount_energy       -0.043282     -0.012595        -0.040874
# forecast_meter_rent_12m         0.065268      0.041393         0.057476
# forecast_price_energy_off_peak -0.007748     -0.017684        -0.005187
# forecast_price_energy_peak      0.145908      0.074002         0.136802
# forecast_price_pow_off_peak    -0.026566     -0.020558        -0.023017
# imp_cons                        0.159711      0.077846         0.187034
# margin_gross_pow_ele           -0.011926      0.006868        -0.011498
# ...

# %% [markdown]
# ---
#
# ## Data visualization

# %%
def plot_stacked_bars(dataframe, title_, size_=(18, 10), rot_=0, legend_="upper right"):
    """
    Plot stacked bars with annotations
    """
    ax = dataframe.plot(
        kind="bar",
        stacked=True,
        figsize=size_,
        rot=rot_,
        title=title_
    )

    # Annotate bars
    annotate_stacked_bars(ax, textsize=14)
    # Rename legend
    plt.legend(["Retention", "Churn"], loc=legend_)
    # Labels
    plt.ylabel("Company base (%)")
    plt.show()

def annotate_stacked_bars(ax, pad=0.99, colour="white", textsize=13):
    """
    Add value annotations to the bars
    """

    # Iterate over the plotted rectanges/bars
    for p in ax.patches:
        
        # Calculate annotation
        value = str(round(p.get_height(),1))
        # If value is 0 do not annotate
        if value == '0.0':
            continue
        ax.annotate(
            value,
            ((p.get_x()+ p.get_width()/2)*pad-0.05, (p.get_y()+p.get_height()/2)*pad),
            color=colour,
            size=textsize
        )

def plot_distribution(dataframe, column, ax, bins_=50):
    """
    Plot variable distirbution in a stacked histogram of churned or retained company
    """
    # Create a temporal dataframe with the data to be plot
    temp = pd.DataFrame({"Retention": dataframe[dataframe["churn"]==0][column],
    "Churn":dataframe[dataframe["churn"]==1][column]})
    # Plot the histogram
    temp[["Retention","Churn"]].plot(kind='hist', bins=100, ax=ax, stacked=True)
    # X-axis label
    ax.set_xlabel(column)
    # Change the x-axis to plain style
    ax.ticklabel_format(style='plain', axis='x')

# %% [markdown]
# Thhe first function `plot_stacked_bars` is used to plot a stacked bar chart. An example of how you could use this is shown below:

# %%
churn = client_df[['id', 'churn']]
churn.columns = ['Companies', 'churn']
churn_total = churn.groupby(churn['churn']).count()
churn_percentage = churn_total / churn_total.sum() * 100
print(churn_percentage)
plot_stacked_bars(churn_percentage.transpose(), "Churning status", (5, 5), legend_="lower right")
# Out:
#        Companies
# churn
# 0      90.284814
# 1       9.715186

# %% [markdown]
# The second function `annotate_bars` is used by the first function, but the third function `plot_distribution` helps you to plot the distribution of a numeric column. An example of how it can be used is given below:

# %%
consumption = client_df[['id', 'cons_12m', 'cons_gas_12m', 'cons_last_month', 'imp_cons', 'has_gas', 'churn']]

fig, axs = plt.subplots(nrows=1, figsize=(18, 5))

plot_distribution(consumption, 'cons_12m', axs)

# %%
#Heatmap showing the correlation between the variables
sns.heatmap(client_df[['cons_12m', 'cons_gas_12m', 'cons_last_month',
       'forecast_cons_12m', 'forecast_cons_year', 'forecast_discount_energy',
       'forecast_meter_rent_12m', 'forecast_price_energy_off_peak',
       'forecast_price_energy_peak', 'forecast_price_pow_off_peak',
       'imp_cons', 'margin_gross_pow_ele', 'margin_net_pow_ele', 'nb_prod_act',
       'net_margin', 'num_years_antig', 'pow_max', 'churn']].corr())
# Out:
# <Axes: >

# %%
temp1 = client_df.groupby(['channel_sales'], as_index=False).count()[['channel_sales','churn']]
temp2 = client_df.groupby(['channel_sales','has_gas'], as_index=False).sum()[['channel_sales','has_gas','churn']]

# %%
temp1.set_index('channel_sales', inplace=True)
temp2.set_index('channel_sales', inplace=True)

# %%
temp1.columns=['count']

# %%
temp3 = temp2.merge(temp1, left_index=True, right_index=True)
temp3
# Out:
#                                  has_gas  churn  count
# channel_sales
# MISSING                                f    234   3725
# MISSING                                t     49   3725
# epumfxlbckeskwekxbiuasklxalciiuu       f      0      3
# ewpakwlliwisiwduibdlfmalxowmwpci       f     64    893
# ewpakwlliwisiwduibdlfmalxowmwpci       t     11    893
# fixdbufsefwooaasfcxdxadsiekoceaa       f      0      2
# fixdbufsefwooaasfcxdxadsiekoceaa       t      0      2
# foosdfpfkusacimwkcsosbicdxkicaua       f    705   6754
# foosdfpfkusacimwkcsosbicdxkicaua       t    115   6754
# lmkebamcaaclubfxadlmueccxoimlema       f     82   1843
# lmkebamcaaclubfxadlmueccxoimlema       t     21   1843
# sddiedcslfslkckwlfkdpoeeailfpeds       f      0     11
# usilxuppasemubllopkaafesmlibmsdf       f    117   1375
# usilxuppasemubllopkaafesmlibmsdf       t     21   1375

# %%
temp3.reset_index(inplace=True)

# %%
temp3['percentage'] = (temp3['churn']/temp3['count'])*100
temp3.drop(['churn','count'], axis=1, inplace=True)

# %% [markdown]
# Visualising which channels and gas connection affecting churn

# %%
pivot_df = temp3.pivot(index='channel_sales', columns='has_gas', values='percentage').fillna(0)
# Plot stacked bars
ax = pivot_df.plot(kind='bar', stacked=True, figsize=(10,7))
pad = 0.98
for p in ax.patches:
        
        # Calculate annotation
        value = str(round(p.get_height(),1))
        # If value is 0 do not annotate
        if value == '0.0':
            continue
        ax.annotate(
            value,
            ((p.get_x()+ p.get_width()/2)*pad-0.05, (p.get_y()+p.get_height()/2)*pad),
            color='white',
            # size=textsize
        )
ax.legend(['No','Yes'], title='Has Gas Conncection')
plt.ylabel('Churn Percentage')
# Out:
# Text(0, 0.5, 'Churn Percentage')

# %% [markdown]
# Summary of distribution of each column

# %%
client_df.columns
# Out:
# Index(['id', 'channel_sales', 'cons_12m', 'cons_gas_12m', 'cons_last_month',
#        'date_activ', 'date_end', 'date_modif_prod', 'date_renewal',
#        'forecast_cons_12m', 'forecast_cons_year', 'forecast_discount_energy',
#        'forecast_meter_rent_12m', 'forecast_price_energy_off_peak',
#        'forecast_price_energy_peak', 'forecast_price_pow_off_peak', 'has_gas',
#        'imp_cons', 'margin_gross_pow_ele', 'margin_net_pow_ele', 'nb_prod_act',
#        'net_margin', 'num_years_antig', 'origin_up', 'pow_max', 'churn'],
#       dtype='object')

# %%
sns.boxplot(client_df['cons_12m'], orient='h')
plt.xlim(-1000, 400000)
# Out:
# (-1000.0, 400000.0)

# %%
sns.boxplot(client_df['forecast_cons_year'], orient='h')
plt.xlim(-1000, 5000)
# Out:
# (-1000.0, 5000.0)

# %% [markdown]
# As we can see from the box plots that almost all the columns are heavly skewed. You can find the same in the percentiles of the describe()

# %% [markdown]
# #### Key findings

# %% [markdown]
# 1) Only 20% of the clients uses both electricity and gas
# 2) Nearly half of the clients were acquired through 'foosdfpfkusacimwkcsosbicdxkicaua' channel
# 3) Also the clients got through the above channel are more likely to leave
# 4) Client acquired through 'lmkebamcaaclubfxadlmueccxoimlema' are less likely to leave
# 5) Having a gas connection along with electricity does not show much impact on churn
